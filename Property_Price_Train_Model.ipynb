# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import numpy as np

# %%
ppt=pd.read_csv(r"C:\Users\kulde\Downloads\Property_Price_Train.csv")

# %%
ppt.head()
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type Lot_Configuration Property_Slope  \
# 0            Reg          Lvl       AllPub                 I             GS
# 1            Reg          Lvl       AllPub              FR2P             GS
# 2            IR1          Lvl       AllPub                 I             GS
# 3            IR1          Lvl       AllPub                 C             GS
# 4            IR1          Lvl       AllPub              FR2P             GS
#
# ...

# %%
ppt.tail()
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 1454  1455              20          FVR        62.0      7500     Paved
# 1455  1456              60          RLD        62.0      7917     Paved
# 1456  1457              20          RLD        85.0     13175     Paved
# 1457  1458              70          RLD        66.0      9042     Paved
# 1458  1459              20          RLD        68.0      9717     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type Lot_Configuration  \
# 1454     Paved            Reg          Lvl       AllPub                 I
# 1455       NaN            Reg          Lvl       AllPub                 I
# 1456       NaN            Reg          Lvl       AllPub                 I
# 1457       NaN            Reg          Lvl       AllPub                 I
# 1458       NaN            Reg          Lvl       AllPub                 I
#
#      Property_Slope Neighborhood Condition1 Condition2 House_Type  \
# ...

# %%
ppt.describe()
# Out:
#                 Id  Building_Class   Lot_Extent       Lot_Size  \
# count  1459.000000     1459.000000  1200.000000    1459.000000
# mean    730.000000       56.922550    70.045833   10517.225497
# std     421.321334       42.304033    24.294456    9984.675721
# min       1.000000       20.000000    21.000000    1300.000000
# 25%     365.500000       20.000000    59.000000    7549.000000
# 50%     730.000000       50.000000    69.000000    9477.000000
# 75%    1094.500000       70.000000    80.000000   11603.000000
# max    1459.000000      190.000000   313.000000  215245.000000
#
#        Overall_Material  House_Condition  Construction_Year  Remodel_Year  \
# count       1459.000000      1459.000000        1459.000000   1459.000000
# mean           6.100069         5.575051        1971.272104   1984.879369
# std            1.383171         1.113125          30.212814     20.645927
# min            1.000000         1.000000        1872.000000   1950.000000
# ...

# %%
ppt.shape
# Out:
# (1459, 81)

# %%
ppt.isnull().sum()
# Out:
# Id                              0
# Building_Class                  0
# Zoning_Class                    0
# Lot_Extent                    259
# Lot_Size                        0
# Road_Type                       0
# Lane_Type                    1368
# Property_Shape                  0
# Land_Outline                    0
# Utility_Type                    0
# Lot_Configuration               0
# Property_Slope                  0
# Neighborhood                    0
# Condition1                      0
# Condition2                      0
# House_Type                      0
# House_Design                    0
# Overall_Material                0
# House_Condition                 0
# Construction_Year               0
# Remodel_Year                    0
# Roof_Design                     0
# Roof_Quality                    0
# Exterior1st                     0
# Exterior2nd                     0
# Brick_Veneer_Type             871
# Brick_Veneer_Area               8
# ...

# %%
len(ppt.isnull().sum()[ppt.isnull().sum()>0])
# Out:
# 19

# %%
ppt.isnull().sum()[ppt.isnull().sum()*100/ppt.shape[0]>45]
# Out:
# Lane_Type                1368
# Brick_Veneer_Type         871
# Fireplace_Quality         689
# Pool_Quality             1452
# Fence_Quality            1178
# Miscellaneous_Feature    1405
# dtype: int64

# %%
ppt.Lot_Extent=ppt.Lot_Extent.fillna(ppt.Lot_Extent.mean())

# %%
ppt.Basement_Height.value_counts()
# Out:
# Basement_Height
# TA    648
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64

# %%
ppt.Basement_Height.fillna("TA",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\3995718336.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.Basement_Height.fillna("TA",inplace=True)

# %%
ppt.Basement_Condition.value_counts()
# Out:
# Basement_Condition
# TA    1310
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64

# %%
ppt.Basement_Condition.fillna("TA",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\3701809907.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.Basement_Condition.fillna("TA",inplace=True)

# %%
ppt.Brick_Veneer_Area=ppt.Brick_Veneer_Area.fillna(ppt.Brick_Veneer_Area.mean())

# %%
ppt.Exposure_Level.value_counts()
# Out:
# Exposure_Level
# No    952
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64

# %%
ppt.Exposure_Level.fillna("No",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\677024157.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.Exposure_Level.fillna("No",inplace=True)

# %%
ppt.BsmtFinType1.value_counts()
# Out:
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    147
# Rec    133
# LwQ     74
# Name: count, dtype: int64

# %%
ppt.BsmtFinType1.fillna("Unf",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\1975433721.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.BsmtFinType1.fillna("Unf",inplace=True)

# %%
ppt.BsmtFinType2.value_counts()
# Out:
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      45
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64

# %%
ppt.BsmtFinType2.fillna("Unf",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\2876078185.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.BsmtFinType2.fillna("Unf",inplace=True)

# %%
ppt.Electrical_System.value_counts()
# Out:
# Electrical_System
# SBrkr    1333
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
ppt.Electrical_System.fillna("SBrkr",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\1864337043.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.Electrical_System.fillna("SBrkr",inplace=True)

# %%
ppt.Garage.value_counts()
# Out:
# Garage
# Attchd     869
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2TFes        5
# 2Types       1
# Name: count, dtype: int64

# %%
ppt.Garage.fillna("Attchd",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\2660615776.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.Garage.fillna("Attchd",inplace=True)

# %%
ppt.Garage_Built_Year=ppt.Garage_Built_Year.fillna(ppt.Garage_Built_Year.mean())

# %%
ppt.Garage_Finish_Year.value_counts()
# Out:
# Garage_Finish_Year
# Unf    605
# RFn    422
# Fin    351
# Name: count, dtype: int64

# %%
ppt.Garage_Finish_Year.fillna("Unf",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\2233362546.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.Garage_Finish_Year.fillna("Unf",inplace=True)

# %%
ppt.Garage_Quality.value_counts()
# Out:
# Garage_Quality
# TA    1310
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
ppt.Garage_Quality.fillna("TA",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\3879395744.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.Garage_Quality.fillna("TA",inplace=True)

# %%
ppt.Garage_Condition.value_counts()
# Out:
# Garage_Condition
# TA    1325
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: count, dtype: int64

# %%
ppt.Garage_Condition.fillna("TA",inplace=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_29144\2491677926.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ppt.Garage_Condition.fillna("TA",inplace=True)

# %%
ppt.drop(["Id", "Lane_Type", "Brick_Veneer_Type","Fireplace_Quality", "Fence_Quality","Pool_Quality","Miscellaneous_Feature"],axis=1,inplace=True,errors='ignore')

# %%
ppt.isnull().sum()
# Out:
# Building_Class               0
# Zoning_Class                 0
# Lot_Extent                   0
# Lot_Size                     0
# Road_Type                    0
# Property_Shape               0
# Land_Outline                 0
# Utility_Type                 0
# Lot_Configuration            0
# Property_Slope               0
# Neighborhood                 0
# Condition1                   0
# Condition2                   0
# House_Type                   0
# House_Design                 0
# Overall_Material             0
# House_Condition              0
# Construction_Year            0
# Remodel_Year                 0
# Roof_Design                  0
# Roof_Quality                 0
# Exterior1st                  0
# Exterior2nd                  0
# Brick_Veneer_Area            0
# Exterior_Material            0
# Exterior_Condition           0
# Foundation_Type              0
# Basement_Height              0
# Basement_Condition           0
# Exposure_Level               0
# ...

# %%
# ppt.Zoning_Class=ppt.Zoning_Class.replace({"RLD":0,"RMD":1,"FVR":2,"RHD":3,"Commer":4})

# %%
# ppt.Road_Type=ppt.Road_Type.replace({"Paved":0,"Gravel":1})

# %%
# ppt.Property_Shape=ppt.Property_Shape.replace({"Reg":0,"IR1":1,"IR2":2,"IR3":3})

# %%
# ppt.Land_Outline=ppt.Land_Outline.replace({"Lvl":0,"Bnk":1,"HLS":2,"Low":3})

# %%
# ppt.Utility_Type=ppt.Utility_Type.replace({"AllPub":0,"NoSeWa":1})

# %%
# ppt.Lot_Configuration=ppt.Lot_Configuration.replace({"I":0,"C":1,"CulDSac":2,"FR2P":3,"FR3P":4})

# %%
# ppt.Property_Slope=ppt.Property_Slope.replace({"GS":0,"MS":1,"SS":2})

# %%
# ppt.Neighborhood=ppt.Neighborhood.replace({"NAmes":0,"CollgCr":1,"OldTown":2,"Edwards":3,"Somerst":4,"Gilbert":5,"NridgHt":6, "Sawyer":7,"NWAmes":8,"SawyerW":9,"BrkSide":10,"Crawfor":11,"Mitchel":12,"NoRidge":13, "Timber":14,"IDOTRR":15,"ClearCr":16,"StoneBr":17,"SWISU":18,"MeadowV":19,"Blmngtn":20,"BrDale":21,"Veenker":22,"NPkVill":23,"Blueste":24})

# %%
# ppt.Condition1=ppt.Condition1.replace({"Norm":0,"Feedr":1,"Artery":2,"RRAn":3,"PosN":4,"RRAe":5,"PosA":6,"RRNn":7,"RRNe":8})

# %%
# ppt.Condition2=ppt.Condition2.replace({"Norm":0,"Feedr":1,"Artery":2,"RRNn":3,"PosN":4,"PosA":5,"RRAn":6,"RRAe":7})

# %%
# ppt.House_Type=ppt.House_Type.replace({"1Fam":0,"TwnhsE":1,"Duplex":2,"Twnhs":3,"2fmCon":4})

# %%
# ppt.House_Design=ppt.House_Design.replace({"1Story":0,"2Story":1,"1.5Fin":2,"SLvl":3,"SFoyer":4,"1.5Unf":5,"2.5Unf":6,"2.5Fin":7})

# %%
# ppt.Roof_Design=ppt.Roof_Design.replace({"Gable":0,"Hip":1,"Flat":2,"Gambrel":3,"Mansard":4,"Shed":5})

# %%
# ppt.Roof_Quality=ppt.Roof_Quality.replace({"SS":0,"TG":1,"WSh":2,"WS":3,"ME":4,"M":5,"R":6,"CT":7})

# %%
# ppt.Exterior1st=ppt.Exterior1st.replace({"VinylSd":0,"HdBoard":1,"MetalSd":2,"Wd Sdng":3,"Plywood":4,"CemntBd":5,"BrkFace":6,"WdShing":7,"Stucco":8,"AsbShng":9,"BrkComm":10,"Stone":11,"AsphShn":12,"ImStucc":13, "CBlock":14})

# %%
# ppt.Exterior2nd=ppt.Exterior2nd.replace({"VinylSd":0,"MetalSd":1,"HdBoard":2,"Wd Sdng":3,"Plywood":4,"CmentBd":5,"Wd Shng":6,
                                           # "Stucco":7,"BrkFace":8,"AsbShng":9,"ImStucc":10,"Brk Cmn":11,"Stone":12,"AsphShn":13,
                                           # "Other":14,"CBlock":15})

# %%
# ppt.Exterior_Material=ppt.Exterior_Material.replace({"TA":0,"Gd":1,"Ex":2,"Fa":3})

# %%
# ppt.Exterior_Condition=ppt.Exterior_Condition.replace({"TA":0,"Gd":1,"Fa":2,"Ex":3,"Po":4})

# %%
# ppt.Foundation_Type=ppt.Foundation_Type.replace({"PC":0,"CB":1,"BT":2,"SL":3,"S":4,"W":5})

# %%
# ppt.Basement_Height=ppt.Basement_Height.replace({"TA":0,"Gd":1,"Ex":2,"Fa":3})

# %%
# ppt.Basement_Condition=ppt.Basement_Condition.replace({"TA":0,"Gd":1,"Fa":2,"Po":3})

# %%
# ppt.Exposure_Level=ppt.Exposure_Level.replace({"No":0,"Av":1,"Gd":2,"Mn":3})

# %%
# ppt.BsmtFinType1=ppt.BsmtFinType1.replace({"Unf":0,"GLQ":1,"ALQ":2,"BLQ":3,"Rec":4,"LwQ":5})

# %%
# ppt.BsmtFinType2=ppt.BsmtFinType2.replace({"Unf":0,"Rec":1,"LwQ":2,"BLQ":3,"ALQ":4,"GLQ":5})

# %%
# ppt.Heating_Type=ppt.Heating_Type.replace({"GasA":0,"GasW":1,"Grav":2,"Wall":3,"OthW":4,"Floor":5})

# %%
# ppt.Heating_Quality=ppt.Heating_Quality.replace({"Ex":0,"TA":1,"Gd":2,"Fa":3,"Po":4})

# %%
# ppt.Air_Conditioning=ppt.Air_Conditioning.replace({"Y":0,"N":1})

# %%
# ppt.Electrical_System=ppt.Electrical_System.replace({"SBrkr":0,"FuseA":1,"FuseF":2,"FuseP":3,"Mix":4})

# %%
# ppt.Kitchen_Quality=ppt.Kitchen_Quality.replace({"TA":0,"Gd":1,"Ex":2,"Fa":3})

# %%
# ppt.Functional_Rate=ppt.Functional_Rate.replace({"TF":0,"MD2":1,"MD1":2,"MajD1":3,"MD":4,"MajD2":5,"SD":6,"MS":7})

# %%
# ppt.Garage=ppt.Garage.replace({"Attchd":0,"Detchd":1,"BuiltIn":2,"Basment":3,"CarPort":4,"2TFes":5,"2Types":6})

# %%
# ppt.Garage_Finish_Year=ppt.Garage_Finish_Year.replace({"Unf":0,"RFn":1,"Fin":2})

# %%
# ppt.Garage_Quality=ppt.Garage_Quality.replace({"TA":0,"Fa":1,"Gd":2,"Ex":3,"Po":4})

# %%
# ppt.Garage_Condition=ppt.Garage_Condition.replace({"TA":0,"Fa":1,"Gd":2,"Po":3,"Ex":4})

# %%
# ppt.Pavedd_Drive=ppt.Pavedd_Drive.replace({"Y":0,"N":1,"P":2})

# %%
# ppt.Sale_Type=ppt.Sale_Type.replace({"WD":0,"New":1,"COD":2,"ConLD":3,"ConLI":4,"ConLw":5,"CWD":6,"Oth":7,"Con":8})

# %%
# ppt.Sale_Condition=ppt.Sale_Condition.replace({"Normal":0,"Partial":1,"Abnorml":2,"Family":3,"Alloca":4,"AdjLand":5})

# %%
ppt.head()
# Out:
#    Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Property_Shape  \
# 0              60          RLD        65.0      8450     Paved            Reg
# 1              20          RLD        80.0      9600     Paved            Reg
# 2              60          RLD        68.0     11250     Paved            IR1
# 3              70          RLD        60.0      9550     Paved            IR1
# 4              60          RLD        84.0     14260     Paved            IR1
#
#   Land_Outline Utility_Type Lot_Configuration Property_Slope Neighborhood  \
# 0          Lvl       AllPub                 I             GS      CollgCr
# 1          Lvl       AllPub              FR2P             GS      Veenker
# 2          Lvl       AllPub                 I             GS      CollgCr
# 3          Lvl       AllPub                 C             GS      Crawfor
# 4          Lvl       AllPub              FR2P             GS      NoRidge
#
# ...

# %%
ppt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 74 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Building_Class             1459 non-null   int64
#  1   Zoning_Class               1459 non-null   object
#  2   Lot_Extent                 1459 non-null   float64
#  3   Lot_Size                   1459 non-null   int64
#  4   Road_Type                  1459 non-null   object
#  5   Property_Shape             1459 non-null   object
#  6   Land_Outline               1459 non-null   object
#  7   Utility_Type               1459 non-null   object
#  8   Lot_Configuration          1459 non-null   object
#  9   Property_Slope             1459 non-null   object
#  10  Neighborhood               1459 non-null   object
#  11  Condition1                 1459 non-null   object
#  12  Condition2                 1459 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
ppt[ppt.select_dtypes(include=["object"]).columns]= ppt[ppt.select_dtypes(include=["object"]).columns].apply(le.fit_transform)

# %%
ppt.head()
# Out:
#    Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Road_Type  \
# 0              60             3        65.0      8450          1
# 1              20             3        80.0      9600          1
# 2              60             3        68.0     11250          1
# 3              70             3        60.0      9550          1
# 4              60             3        84.0     14260          1
#
#    Property_Shape  Land_Outline  Utility_Type  Lot_Configuration  \
# 0               3             3             0                  4
# 1               3             3             0                  2
# 2               0             3             0                  4
# 3               0             3             0                  0
# 4               0             3             0                  2
#
#    Property_Slope  Neighborhood  Condition1  Condition2  House_Type  \
# 0               0             5           2           2           0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
ppt = df1

# %%
ppt_train, ppt_test = train_test_split(ppt, test_size=0.25)

# %%
ppt_train.shape
# Out:
# (1003, 74)

# %%
ppt_test.shape
# Out:
# (335, 74)

# %%
ppt_train_x = ppt_train.iloc[:, 0:-1]
ppt_train_y = ppt_train.iloc[:, -1]

# %%
ppt_test_x = ppt_test.iloc[:, 0:-1]
ppt_test_y  = ppt_test.iloc[:, -1]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(ppt_train_x,ppt_train_y)
# Out:
# LinearRegression()

# %%
#1.Rsquare
Rsquare=lr.score(ppt_train_x,ppt_train_y)
Rsquare
# Out:
# 0.8361317074439045

# %%
#2. Adjected Rsq.
ppt.shape
# Out:
# (1338, 74)

# %%
N=ppt_train_x.shape[0]
K=ppt_train_x.shape[1]
K
# Out:
# 73

# %%
Adj_Rsquare=1-(1-Rsquare)*(N-1)/(N-K-1)
Adj_Rsquare
# Out:
# 0.8232550816563965

# %%
lr.coef_
# Out:
# array([-6.37312756e+01, -4.99976081e+03, -7.26564903e+01,  5.28685731e-02,
#         3.48992126e+04, -9.83114951e+02,  2.30964822e+03, -3.67192872e+04,
#        -4.72257828e+02,  5.57516748e+03,  1.47348521e+02, -1.04865047e+02,
#        -5.74652389e+03, -2.46585597e+03, -1.00391997e+03,  8.62420465e+03,
#         4.49164717e+03,  2.29014316e+02,  1.60891168e+02,  1.35487287e+02,
#         2.33155608e+04, -6.54062602e+02,  4.64903412e+02,  3.57551243e+00,
#        -1.08445550e+03,  4.78729824e+02,  1.55603562e+03, -2.78957285e+03,
#         2.35720867e+03, -2.75781267e+03, -1.42825547e+03, -5.57387469e-01,
#        -3.99068970e+01,  4.09384056e+00,  2.05751331e+00,  5.59396634e+00,
#        -2.00851464e+03, -1.57622178e+03, -2.20507887e+03, -5.94825842e+02,
#         7.54351247e+00,  1.27203878e+01, -6.21686465e-01,  1.96422138e+01,
#         7.87178239e+03,  1.85452016e+03,  5.17813094e+03, -4.84364889e+01,
# ...

# %%
lr.intercept_
# Out:
# 776802.1435061209

# %%
pred_train=lr.predict(ppt_train_x)
pred_test=lr.predict(ppt_test_x)

# %%
err_test=ppt_test_y-pred_test
err_test
# Out:
# 1337    -16988.182753
# 123      -2622.166096
# 1300      4606.314396
# 1121    -11537.548686
# 201       1060.226525
# 332      34454.481196
# 1038      3529.164902
# 397      17097.526049
# 78       26284.114224
# 1041     -7715.261033
# 1189     -6786.813942
# 1392     -6133.938783
# 387     -15225.787358
# 509      -9451.525916
# 1100     19461.319744
# 57       -1636.039987
# 950     -20940.785280
# 1147     18654.864033
# 469      -4024.920966
# 966      41613.708264
# 86      -14634.414750
# 1410     25882.423135
# 852       4509.157253
# 796     -14771.030454
# 669      30684.931353
# 998      20468.855177
# 599     -12941.234934
# 817      22719.064284
# 605      -6337.611306
# 1346     41745.360247
# 680      17635.412439
# 602      -3499.504949
# 517      29801.341429
# 996       8865.017083
# 1237    -21373.007299
# 173      -5086.249379
# 249      35309.663281
# 265      -9077.860161
# 925       2876.412415
# 274      -6021.186432
# 406     -10995.171661
# ...

# %%
err_train=ppt_train_y-pred_train
err_train
# Out:
# 329    -7.965104e+03
# 976    -1.057450e+03
# 127    -2.929474e+03
# 684     2.719598e+04
# 199     8.102346e+02
# 963     2.404291e+02
# 965    -1.142762e+04
# 1265   -3.952992e+03
# 1393    1.286935e+04
# 287    -1.433438e+03
# 609     5.452272e+03
# 334    -1.273148e+04
# 436    -1.684109e+04
# 850    -1.983747e+04
# 135    -1.062567e+04
# 651    -5.052053e+03
# 912     2.541097e+03
# 1004   -8.005803e+03
# 1277    5.352018e+03
# 1208   -1.453241e+03
# 719    -1.120385e+04
# 1441   -4.565202e+03
# 641    -5.562530e+03
# 5      -2.664201e+04
# 55      7.056293e+03
# 917     1.319454e+04
# 1117   -3.075806e+04
# 296     2.870401e+04
# 934     5.664167e+03
# 1440    3.612839e+03
# 1439    1.845170e+04
# 483    -9.652460e+02
# 813     1.186489e+04
# 520     2.993728e+04
# 220     3.248865e+03
# 1357   -1.547770e+04
# 849     1.290609e+03
# 152     4.924244e+03
# 550    -7.191495e+02
# 340    -1.155660e+04
# 1078    4.765592e+03
# 446    -3.464868e+03
# 747     5.332028e+04
# ...

# %%
#3. Mean Square Error(MSE)
mse_test=np.mean(np.square(err_test))
mse_test
# Out:
# 472765904.3375589

# %%
mse_train=np.mean(np.square(err_train))
mse_train
# Out:
# 420075622.989926

# %%
#4. Root mean square error(RMSE)
rmse_test=np.sqrt(mse_test)
rmse_test
# Out:
# 21743.180639859453

# %%
rmse_train=np.sqrt(mse_train)
rmse_train
# Out:
# 20495.746460910515

# %%
#5. MAPE
mape=np.mean(np.abs(err_test*100/ppt_test_y))
mape
# Out:
# 9.698753878186755

# %%
err_train=ppt_train_y-pred_train
err_train
# Out:
# 329    -7.965104e+03
# 976    -1.057450e+03
# 127    -2.929474e+03
# 684     2.719598e+04
# 199     8.102346e+02
# 963     2.404291e+02
# 965    -1.142762e+04
# 1265   -3.952992e+03
# 1393    1.286935e+04
# 287    -1.433438e+03
# 609     5.452272e+03
# 334    -1.273148e+04
# 436    -1.684109e+04
# 850    -1.983747e+04
# 135    -1.062567e+04
# 651    -5.052053e+03
# 912     2.541097e+03
# 1004   -8.005803e+03
# 1277    5.352018e+03
# 1208   -1.453241e+03
# 719    -1.120385e+04
# 1441   -4.565202e+03
# 641    -5.562530e+03
# 5      -2.664201e+04
# 55      7.056293e+03
# 917     1.319454e+04
# 1117   -3.075806e+04
# 296     2.870401e+04
# 934     5.664167e+03
# 1440    3.612839e+03
# 1439    1.845170e+04
# 483    -9.652460e+02
# 813     1.186489e+04
# 520     2.993728e+04
# 220     3.248865e+03
# 1357   -1.547770e+04
# 849     1.290609e+03
# 152     4.924244e+03
# 550    -7.191495e+02
# 340    -1.155660e+04
# 1078    4.765592e+03
# 446    -3.464868e+03
# 747     5.332028e+04
# ...

# %%
np.mean(err_train)
# Out:
# 4.0745362639427185e-10

# %%
import matplotlib.pyplot as plt
plt.plot(err_train,"*")

# %%
plt.hist(err_train,bins=15,edgecolor="red")
plt.show()

# %%
pred_actual_df=pd.DataFrame()

# %%
pred_actual_df["Actual"]=ppt_train_y
pred_actual_df["Predicted"]=pred_train
pred_actual_df
# Out:
#       Actual      Predicted
# 329    78000   85965.103845
# 976    85500   86557.450452
# 127    87000   89929.473939
# 684   221000  193804.019182
# 199   274900  274089.765397
# 963   239000  238759.570897
# 965   178900  190327.618789
# 1265  183900  187852.991911
# 1393  163000  150130.651814
# 287    88000   89433.437657
# 609   118500  113047.728299
# 334   192000  204731.481531
# 436   116000  132841.094490
# 850   131500  151337.472959
# 135   174000  184625.674132
# 651   108000  113052.053438
# 912    88000   85458.903223
# 1004  181000  189005.803177
# 1277  197900  192547.981877
# 1208  140000  141453.240872
# 719   128500  139703.852434
# 1441  149300  153865.202212
# 641   226000  231562.530062
# 5     143000  169642.014289
# 55    180500  173443.707105
# 917   135000  121805.460318
# 1117  130000  160758.060610
# 296   152000  123295.990118
# 934   242000  236335.832779
# 1440  191000  187387.161163
# 1439  197000  178548.296603
# 483   164000  164965.246006
# ...

# %%
import seaborn as sns
sns.jointplot(x="Actual",y="Predicted",data=pred_actual_df,kind="reg")

# %%
def remove_outliers(df,col,k):
    mean = df[col].mean()
    global df1
    sd = df[col].std()
    final_list = [x for x in df[col] if(x>mean-k*sd)]
    final_list = [x for x in final_list if(x<mean+k*sd)]
    df1 = df.loc[df[col].isin(final_list)]; print(df1.shape)
    print("Number of outlier removed -------> ", df.shape[0] - df.shape[0])

# %%
remove_outliers(ppt, "Sale_Price", 2)
# Out:
# (1270, 74)
# Number of outlier removed ------->  0
